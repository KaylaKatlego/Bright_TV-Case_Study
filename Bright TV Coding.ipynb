-- %%
USE bright_tv.dataset

SELECT*
FROM bright_tv.dataset.user_profiles

SELECT *
FROM bright_tv.dataset.viewership

SELECT COUNT(*), userid
FROM bright_tv.dataset.user_profiles
GROUP BY userid
HAVING COUNT(*) > 1;
